# %% [markdown]
# # 1D Structure Function / Mooring Data
#
# This example will guide you through each step necessary to compute scalar-based structure functions from a 1D time series of ocean currents.
#
# $\textbf{General procedure}:$
#
#
# 1 -  Load the dataset, it can retrieved from https://www.ncei.noaa.gov
#
# 2 -  Format dataset to match pyturbo_sf inputs if necessary
#
# 3 -  Calculate second-order zonal current structure function as a function of separation time
#
# 4 -  Quick comparison between no bootstrapping and bootstrapping in 1D - which shows in this specific case the inefficiency of pyturbo (check executed time)
#
# 5 -  Plot the 1D SF
#
# $\textbf{Motivation:}$ This example shows the 1D structure function computation using pyturbo on time series. The 1D structure function might reveal some time scales at which turbulent energy is transferred in the ocean.

# %%
import xarray as xr
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm, SymLogNorm
import matplotlib.ticker as ticker
import pyturbo_sf as psf
import numpy as np
linewidth = 2
fontsize = 12
plt.rcParams['xtick.labelsize'] = fontsize
plt.rcParams['ytick.labelsize'] = fontsize
plt.rcParams['xtick.major.width'] = 2
plt.rcParams['xtick.minor.width'] = 2
plt.rcParams['ytick.major.width'] = 2
plt.rcParams['ytick.minor.width'] = 2
plt.rcParams['xtick.major.size'] = 10
plt.rcParams['xtick.minor.size'] = 5
plt.rcParams['ytick.major.size'] = 10
plt.rcParams['ytick.minor.size'] = 5
plt.rcParams['savefig.dpi'] = 150
plt.rc('font', family='serif')
import gc

# %% [markdown]
# # Load Mooring Dataset

# %%
ds = xr.open_dataset('/home/aayouche/Téléchargements/gocd_a0060062_7922vm-a.nc')
import datetime
import numpy as np

# Assuming your array is called 'julian_dates'
# Method 1: List comprehension
datetime_dates = [datetime.datetime(dt.year, dt.month, dt.day, 
                                   dt.hour, dt.minute, dt.second, 
                                   dt.microsecond) for dt in ds.time.values]

# Convert back to numpy array if needed
datetime_array = np.array(datetime_dates, dtype='datetime64[us]')

# Convert the time differences to seconds
# First, convert to timedelta64[s] type
delta_seconds = (datetime_array - datetime_array[0]).astype('timedelta64[s]')

# Then convert to floating point numbers representing seconds
delta_seconds_float = delta_seconds.astype(float)

dt_min = 60.0
dt_max = delta_seconds_float.max()
ds
# Out:
# <xarray.Dataset> Size: 436kB
# Dimensions:                 (time: 10898)
# Coordinates:
#     depth                   float32 4B ...
#     latitude                float32 4B ...
#     longitude               float32 4B ...
#   * time                    (time) object 87kB 2005-06-06 13:01:29.999981 ......
# Data variables:
#     crs                     int32 4B ...
#     depth_quality_flag      float64 8B ...
#     latitude_quality_flag   float64 8B ...
#     longitude_quality_flag  float64 8B ...
#     seafloor_depth          float32 4B ...
#     time_quality_flag       (time) float64 87kB ...
#     u                       (time) float32 44kB ...
#     u_quality_flag          (time) float64 87kB ...
#     v                       (time) float32 44kB ...
#     v_quality_flag          (time) float64 87kB ...
# Attributes: (12/72)
#     acknowledgment:                  The most important contributors are the ...
#     cdm_data_type:                   Station
#     comment:                         Data that have been undergone additional...
#     contributor_name:                B. Butman, M. Bothner, and R. Signell
#     contributor_role:                data originator
#     Conventions:                     CF-1.6, ACDD-1.3
#     ...                              ...
#     QC_test_names:                   Platform_Identification, Impossible_Date...
#     QC_test_codes:                   1, 1, 1, 1, 1, 1, 1, 1, 1
#     QC_test_results:                 1, 1, 1, 2, 1, 1, 1, 1, 1
#     QC_indicator:                    2
#     QC_Software:                     qcscd.R, 1.3, 2015-03-09
#     uuid:                            fb9c3b81-f3da-4043-bb05-1e48f51649b7

# %% [markdown]
# # Make A quick plot

# %%
plt.figure(figsize=(12,6))
plt.plot_date(datetime_array,ds.u.values)
plt.ylabel('u [m/s]')
# Out:
# /tmp/ipykernel_8468/3979089935.py:2: MatplotlibDeprecationWarning: The plot_date function was deprecated in Matplotlib 3.9 and will be removed in 3.11. Use plot instead.
#   plt.plot_date(datetime_array,ds.u.values)
# Text(0, 0.5, 'u\xa0[m/s]')

# %% [markdown]
# # Format Dataset

# %%
# Create the xarray dataset
ds_new = xr.Dataset({
    'u': ('time', ds.u.values), 
    'v': ('time', ds.v.values),
}, coords={
    'time': ('time', datetime_array),
})

# %%
ds_new
# Out:
# <xarray.Dataset> Size: 174kB
# Dimensions:  (time: 10898)
# Coordinates:
#   * time     (time) datetime64[ns] 87kB 2005-06-06T13:01:29.999981 ... 2005-0...
# Data variables:
#     u        (time) float32 44kB -0.1092 -0.1074 -0.1121 ... 0.1221 0.143 0.1627
#     v        (time) float32 44kB -0.121 -0.1255 -0.1168 ... 0.04732 0.04929

# %% [markdown]
# # Compute second order zonal velocity SF (no bootstrapping) - bootsize = dataset size

# %%
# %%time

bin_time = np.logspace(np.log10(dt_min), np.log10(653819.0), 10)
bins = {
    'time': bin_time,
}
iso_sf_lon = psf.bin_sf_1d(
    ds=ds_new,
    variables_names=["u"],
    order=2,
    bins=bins,
    fun='scalar',
    bootsize={'time':10898},
    initial_nbootstrap=100,
    max_nbootstrap=200,
    step_nbootstrap=50,
    convergence_eps=0.02,
    n_jobs = -1,
    backend='loky'
)
# Out:
# Data dimensions and shapes: {'time': 10898}
# Using bootsize: {'time': 10898}
# Dimension time has bootsize equal to or larger than dimension size. No bootstrapping will be done across this dimension.
# No bootstrappable dimensions available. Structure functions will be calculated using the full dataset without bootstrapping or spacings.
#
# ============================================================
# STARTING BIN_SF WITH FUNCTION TYPE: scalar
# Variables: ['u'], Order: 2
# Bootstrap parameters: initial=100, max=200, step=50
# Convergence threshold: 0.02
# Bootstrappable dimensions: [] (count: 0)
# Using volume element weighting: |dx|
# ============================================================
#
# Detected logarithmic binning for dimension 'time'
#
# No bootstrappable dimensions available. Calculating structure function once with full dataset.
# 1D SF COMPLETED SUCCESSFULLY (no bootstrapping)!
# ============================================================
# CPU times: user 2.92 s, sys: 0 ns, total: 2.92 s
# Wall time: 2.92 s

# %% [markdown]
# # Compute second order zonal velocity SF (no bootstrapping) - bootsize = 16

# %%
# %%time

bin_time = np.logspace(np.log10(dt_min), np.log10(653819.0), 10)
bins = {
    'time': bin_time,
}
iso_sf_lon = psf.bin_sf_1d(
    ds=ds_new,
    variables_names=["u"],
    order=2,
    bins=bins,
    fun='scalar',
    bootsize={'time':16},
    initial_nbootstrap=100,
    max_nbootstrap=200,
    step_nbootstrap=50,
    convergence_eps=0.02,
    n_jobs = -1,
    backend='loky'
)
# Out:
# Data dimensions and shapes: {'time': 10898}
# Using bootsize: {'time': 16}
# Accessible spacings are: [1, 2, 4, 8, 16, 32, 64, 128, 256, 512]
#
# ============================================================
# STARTING BIN_SF WITH FUNCTION TYPE: scalar
# Variables: ['u'], Order: 2
# Bootstrap parameters: initial=100, max=200, step=50
# Convergence threshold: 0.02
# Bootstrappable dimensions: ['time'] (count: 1)
# Using volume element weighting: |dx|
# ============================================================
#
# Detected logarithmic binning for dimension 'time'
# Available spacings: [1, 2, 4, 8, 16, 32, 64, 128, 256, 512]
#
# INITIAL BOOTSTRAP PHASE
#   Processing spacing 1 with 10 bootstraps
#   Processing spacing 2 with 10 bootstraps
#   Processing spacing 4 with 10 bootstraps
#   Processing spacing 8 with 10 bootstraps
#   Processing spacing 16 with 10 bootstraps
#   Processing spacing 32 with 10 bootstraps
#   Processing spacing 64 with 10 bootstraps
#   Processing spacing 128 with 10 bootstraps
#   Processing spacing 256 with 10 bootstraps
#   Processing spacing 512 with 10 bootstraps
#
# CALCULATING BIN DENSITIES
# Total points collected: 216120
# Bins with points: 9/9
# Maximum density bin has 138690 points
# Marked 9 bins as converged (converged_eps)
#
# STARTING ADAPTIVE CONVERGENCE LOOP
# All bins have converged or reached max bootstraps!
#
# FINAL CONVERGENCE STATISTICS:
#   Total bins with data (>10 points): 9
#   Converged bins: 9
#   Unconverged bins: 0
#   Bins at max bootstraps: 0
#
# Creating output dataset...
# 1D SF COMPLETED SUCCESSFULLY!
# ============================================================
# CPU times: user 2.36 s, sys: 224 ms, total: 2.58 s
# Wall time: 13.8 s

# %% [markdown]
# # Compute second order zonal velocity SF (no bootstrapping) - bootsize = 32

# %%
# %%time

bin_time = np.logspace(np.log10(dt_min), np.log10(653819.0), 10)
bins = {
    'time': bin_time,
}
iso_sf_lon = psf.bin_sf_1d(
    ds=ds_new,
    variables_names=["u"],
    order=2,
    bins=bins,
    fun='scalar',
    bootsize={'time':32},
    initial_nbootstrap=100,
    max_nbootstrap=200,
    step_nbootstrap=50,
    convergence_eps=0.02,
    n_jobs = -1,
    backend='loky'
)
# Out:
# Data dimensions and shapes: {'time': 10898}
# Using bootsize: {'time': 32}
# Accessible spacings are: [1, 2, 4, 8, 16, 32, 64, 128, 256]
#
# ============================================================
# STARTING BIN_SF WITH FUNCTION TYPE: scalar
# Variables: ['u'], Order: 2
# Bootstrap parameters: initial=100, max=200, step=50
# Convergence threshold: 0.02
# Bootstrappable dimensions: ['time'] (count: 1)
# Using volume element weighting: |dx|
# ============================================================
#
# Detected logarithmic binning for dimension 'time'
# Available spacings: [1, 2, 4, 8, 16, 32, 64, 128, 256]
#
# INITIAL BOOTSTRAP PHASE
#   Processing spacing 1 with 11 bootstraps
#   Processing spacing 2 with 11 bootstraps
#   Processing spacing 4 with 11 bootstraps
#   Processing spacing 8 with 11 bootstraps
#   Processing spacing 16 with 11 bootstraps
#   Processing spacing 32 with 11 bootstraps
#   Processing spacing 64 with 11 bootstraps
#   Processing spacing 128 with 11 bootstraps
#   Processing spacing 256 with 11 bootstraps
#
# CALCULATING BIN DENSITIES
# Total points collected: 236093
# Bins with points: 9/9
# Maximum density bin has 151030 points
# Marked 9 bins as converged (converged_eps)
#
# STARTING ADAPTIVE CONVERGENCE LOOP
# All bins have converged or reached max bootstraps!
#
# FINAL CONVERGENCE STATISTICS:
#   Total bins with data (>10 points): 9
#   Converged bins: 9
#   Unconverged bins: 0
#   Bins at max bootstraps: 0
#
# Creating output dataset...
# 1D SF COMPLETED SUCCESSFULLY!
# ============================================================
# CPU times: user 1.63 s, sys: 91.6 ms, total: 1.72 s
# Wall time: 10.5 s

# %% [markdown]
# # Compute second order zonal velocity SF (no bootstrapping) - bootsize = 64

# %%
# %%time

bin_time = np.logspace(np.log10(dt_min), np.log10(653819.0), 10)
bins = {
    'time': bin_time,
}
iso_sf_lon = psf.bin_sf_1d(
    ds=ds_new,
    variables_names=["u"],
    order=2,
    bins=bins,
    fun='scalar',
    bootsize={'time':64},
    initial_nbootstrap=100,
    max_nbootstrap=200,
    step_nbootstrap=50,
    convergence_eps=0.02,
    n_jobs = -1,
    backend='loky'
)
# Out:
# Data dimensions and shapes: {'time': 10898}
# Using bootsize: {'time': 64}
# Accessible spacings are: [1, 2, 4, 8, 16, 32, 64, 128]
#
# ============================================================
# STARTING BIN_SF WITH FUNCTION TYPE: scalar
# Variables: ['u'], Order: 2
# Bootstrap parameters: initial=100, max=200, step=50
# Convergence threshold: 0.02
# Bootstrappable dimensions: ['time'] (count: 1)
# Using volume element weighting: |dx|
# ============================================================
#
# Detected logarithmic binning for dimension 'time'
# Available spacings: [1, 2, 4, 8, 16, 32, 64, 128]
#
# INITIAL BOOTSTRAP PHASE
#   Processing spacing 1 with 12 bootstraps
#   Processing spacing 2 with 12 bootstraps
#   Processing spacing 4 with 12 bootstraps
#   Processing spacing 8 with 12 bootstraps
#   Processing spacing 16 with 12 bootstraps
#   Processing spacing 32 with 12 bootstraps
#   Processing spacing 64 with 12 bootstraps
#   Processing spacing 128 with 12 bootstraps
#
# CALCULATING BIN DENSITIES
# Total points collected: 254364
# Bins with points: 9/9
# Maximum density bin has 161796 points
# Marked 9 bins as converged (converged_eps)
#
# STARTING ADAPTIVE CONVERGENCE LOOP
# All bins have converged or reached max bootstraps!
#
# FINAL CONVERGENCE STATISTICS:
#   Total bins with data (>10 points): 9
#   Converged bins: 9
#   Unconverged bins: 0
#   Bins at max bootstraps: 0
#
# Creating output dataset...
# 1D SF COMPLETED SUCCESSFULLY!
# ============================================================
# CPU times: user 1.72 s, sys: 103 ms, total: 1.83 s
# Wall time: 11.4 s

# %% [markdown]
# # Compute second order zonal velocity SF (no bootstrapping) - bootsize = 128

# %%
# %%time

bin_time = np.logspace(np.log10(dt_min), np.log10(653819.0), 10)
bins = {
    'time': bin_time,
}
iso_sf_lon = psf.bin_sf_1d(
    ds=ds_new,
    variables_names=["u"],
    order=2,
    bins=bins,
    fun='scalar',
    bootsize={'time':128},
    initial_nbootstrap=100,
    max_nbootstrap=200,
    step_nbootstrap=50,
    convergence_eps=0.02,
    n_jobs = -1,
    backend='loky'
)
# Out:
# Data dimensions and shapes: {'time': 10898}
# Using bootsize: {'time': 128}
# Accessible spacings are: [1, 2, 4, 8, 16, 32, 64]
#
# ============================================================
# STARTING BIN_SF WITH FUNCTION TYPE: scalar
# Variables: ['u'], Order: 2
# Bootstrap parameters: initial=100, max=200, step=50
# Convergence threshold: 0.02
# Bootstrappable dimensions: ['time'] (count: 1)
# Using volume element weighting: |dx|
# ============================================================
#
# Detected logarithmic binning for dimension 'time'
# Available spacings: [1, 2, 4, 8, 16, 32, 64]
#
# INITIAL BOOTSTRAP PHASE
#   Processing spacing 1 with 14 bootstraps
#   Processing spacing 2 with 14 bootstraps
#   Processing spacing 4 with 14 bootstraps
#   Processing spacing 8 with 14 bootstraps
#   Processing spacing 16 with 14 bootstraps
#   Processing spacing 32 with 14 bootstraps
#   Processing spacing 64 with 14 bootstraps
#
# CALCULATING BIN DENSITIES
# Total points collected: 290192
# Bins with points: 9/9
# Maximum density bin has 182742 points
# Marked 9 bins as converged (converged_eps)
#
# STARTING ADAPTIVE CONVERGENCE LOOP
# All bins have converged or reached max bootstraps!
#
# FINAL CONVERGENCE STATISTICS:
#   Total bins with data (>10 points): 9
#   Converged bins: 9
#   Unconverged bins: 0
#   Bins at max bootstraps: 0
#
# Creating output dataset...
# 1D SF COMPLETED SUCCESSFULLY!
# ============================================================
# CPU times: user 2.75 s, sys: 239 ms, total: 2.99 s
# Wall time: 15.2 s

# %% [markdown]
# # Plot second order zonal velocity SF

# %%
# Create separate figures for better spacing and clarity
plt.figure(figsize=(10, 6))
# Structure Function with Confidence Interval
plt.loglog(iso_sf_lon.bin, iso_sf_lon.sf, 'b-', linewidth=2.5)

plt.fill_between(iso_sf_lon.bin, 
                iso_sf_lon.ci_lower, 
                iso_sf_lon.ci_upper, 
                alpha=0.3, color='blue')



# Formatting
plt.xlabel(r'$\delta t$ [s]', fontsize=12, fontweight='bold')
plt.ylabel(r'$\delta u^{2}~[m^{2}~s^{-2}]$', fontsize=12, fontweight='bold')
plt.title('1D zonal velocity Structure Function with Confidence Intervals', 
         fontsize=14, fontweight='bold', pad=10)
plt.grid(True, which='both', linestyle='--', alpha=0.6)
