# %% [markdown]
# # 2D Structure Function Data with TERRA SST
#
# This example will guide you through each step necessary to compute scalar-based structure functions from a 2D data of sea surface temperature.
#
# $\textbf{General procedure}:$
#
#
#     1 -  Load a TERRA dataset generated with https://search.earthdata.nasa.gov
#     2 -  Subset and Format dataset
#     3 -  Calculate 2D scalar-based SST structure function as a function of separation distances
#     4 -  Plot the 2D scalar-based SF with errors and number of bootstraps
#     5 -  Plot Isotropic scalar-based SF with isotropy and homogeneity errors

# %%
import xarray as xr
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm, SymLogNorm
import matplotlib.ticker as ticker
import pyturbo_sf as psf
import pyproj
import numpy as np
linewidth = 2
fontsize = 12
plt.rcParams['xtick.labelsize'] = fontsize
plt.rcParams['ytick.labelsize'] = fontsize
plt.rcParams['xtick.major.width'] = 2
plt.rcParams['xtick.minor.width'] = 2
plt.rcParams['ytick.major.width'] = 2
plt.rcParams['ytick.minor.width'] = 2
plt.rcParams['xtick.major.size'] = 10
plt.rcParams['xtick.minor.size'] = 5
plt.rcParams['ytick.major.size'] = 10
plt.rcParams['ytick.minor.size'] = 5
plt.rcParams['savefig.dpi'] = 150
plt.rc('font', family='serif')
import gc

# %% [markdown]
# # Load the TERRA Dataset

# %%
ds = xr.open_dataset('example_data/TERRA_MODIS.20250201_20250228.L3m.MO.NSST.sst.4km.nc')
subset = ds.sel(lon=slice(-75,-45),lat=slice(42.0,12.0))
subset
# Out:
# <xarray.Dataset> Size: 4MB
# Dimensions:   (lat: 720, lon: 720, rgb: 3, eightbitcolor: 256)
# Coordinates:
#   * lat       (lat) float32 3kB 41.98 41.94 41.9 41.85 ... 12.1 12.06 12.02
#   * lon       (lon) float32 3kB -74.98 -74.94 -74.9 ... -45.1 -45.06 -45.02
# Dimensions without coordinates: rgb, eightbitcolor
# Data variables:
#     sst       (lat, lon) float32 2MB ...
#     qual_sst  (lat, lon) float32 2MB ...
#     palette   (rgb, eightbitcolor) uint8 768B ...
# Attributes: (12/60)
#     product_name:                     TERRA_MODIS.20250201_20250228.L3m.MO.NS...
#     instrument:                       MODIS
#     title:                            MODIST Level-3 Standard Mapped Image
#     project:                          Ocean Biology Processing Group (NASA/GS...
#     platform:                         Terra
#     source:                           satellite observations from MODIS-Terra
#     ...                               ...
#     publisher_url:                    https://oceandata.sci.gsfc.nasa.gov
#     processing_level:                 L3 Mapped
#     cdm_data_type:                    grid
#     data_bins:                        19867739
#     data_minimum:                     -1.8
#     data_maximum:                     34.556667

# %% [markdown]
# # Make A quick Plot

# %%
subset.sst[::-1,:].plot()

# %% [markdown]
# # Format Dataset

# %%
lon_center = np.nanmin(subset.lon)
utm_zone = int(1 + (lon_center + 180.0) / 6.0)
# Create the projection
proj = pyproj.Proj(proj='utm', zone=utm_zone, ellps='WGS84', datum='WGS84')

x, y = proj(subset.lon.values, subset.lat.values[::-1]) # order lat values 

Y,X = np.meshgrid(y,x,indexing='ij')
# Create the xarray dataset
ds_new = xr.Dataset({
    'sst': (['y', 'x'], subset.sst.values[::-1,:]), # order sst according to lat values

}, coords={
    'x': (['y', 'x'], X),
    'y': (['y', 'x'], Y)
})

# %%
ds_new
# Out:
# <xarray.Dataset> Size: 10MB
# Dimensions:  (y: 720, x: 720)
# Coordinates:
#     x        (y, x) float64 4MB 5.023e+05 5.068e+05 ... 2.989e+06 2.991e+06
#     y        (y, x) float64 4MB 1.329e+06 1.329e+06 ... 5.106e+06 5.106e+06
# Data variables:
#     sst      (y, x) float32 2MB 26.58 26.61 26.55 26.5 ... 17.05 nan nan nan

# %% [markdown]
# # Calculate 2D SST SF $\delta T (r_{x},r_{y})$

# %%
bins = {
    'x': np.logspace(np.log10(4534.), np.log10(2.4e6), 11),
    'y': np.logspace(np.log10(4608.), np.log10(3.7e6), 11)
}
sf_result = psf.bin_sf_2d(
    ds=ds_new,
    variables_names=["sst"],
    order=1,
    bins=bins,
    fun='scalar',
    bootsize={'y':32,'x':32},
    initial_nbootstrap=50,
    max_nbootstrap=200,
    step_nbootstrap=50,
    convergence_eps=1.0
)
# Out:
# Dimensions ('y', 'x') are already in the expected order
# Using bootsize: {'y': 32, 'x': 32}
# Bootstrappable dimensions: ['y', 'x']
# Two bootstrappable dimensions. Available spacings: [1, 2, 4, 8, 16]
#
# ============================================================
# STARTING BIN_SF WITH FUNCTION TYPE: scalar
# Variables: ['sst'], Order: 1
# Bootstrap parameters: initial=50, max=200, step=50
# Convergence threshold: 1.0
# Bootstrappable dimensions: ['y', 'x'] (count: 2)
# ============================================================
#
# Bin dimensions: y=10, x=10
# Total bins: 100
# Bin type for x: logarithmic
# Bin type for y: logarithmic
# Available spacings: [1, 2, 4, 8, 16]
#
# INITIAL BOOTSTRAP PHASE
#   Processing spacing 1 with 10 bootstraps
#   Processing spacing 2 with 10 bootstraps
#   Processing spacing 4 with 10 bootstraps
#   Processing spacing 8 with 10 bootstraps
#   Processing spacing 16 with 10 bootstraps
#
# CALCULATING BIN DENSITIES
# Total points collected: 51190
# Bins with points: 91/100
# Maximum density bin has 2097 points
#
# CALCULATING INITIAL STATISTICS
# Marked 9 low-density bins (< 10 points) as converged
# Marked 7 bins with NaN standard deviations as converged
# Marked 45 bins as early-converged (std <= 1.0)
#
# STARTING ADAPTIVE CONVERGENCE LOOP
#
# Iteration 1 - 39 unconverged bins
#
# Processing bin (4,0) - Density: 0.3531 - Current bootstraps: 50 - Current std: 2.998001 - Points: 610
#   Adding 85 more bootstraps to bin (4,0)
#   Processing spacing 1 with 62 bootstraps
#   Processing spacing 2 with 14 bootstraps
#   Processing spacing 4 with 4 bootstraps
#   Processing spacing 8 with 2 bootstraps
#   Processing spacing 16 with 1 bootstraps
#
# Processing bin (3,0) - Density: 0.3424 - Current bootstraps: 50 - Current std: 0.767750 - Points: 303
#   Adding 84 more bootstraps to bin (3,0)
#   Processing spacing 1 with 61 bootstraps
#   Processing spacing 2 with 13 bootstraps
#   Processing spacing 4 with 5 bootstraps
#   Processing spacing 8 with 2 bootstraps
#   Bin (3,0) CONVERGED after additional bootstraps with std 0.797839 <= 1.0
#
# Processing bin (5,0) - Density: 0.1545 - Current bootstraps: 50 - Current std: 2.214163 - Points: 521
#   Adding 65 more bootstraps to bin (5,0)
#   Processing spacing 1 with 27 bootstraps
#   Processing spacing 2 with 23 bootstraps
#   Processing spacing 4 with 7 bootstraps
#   Processing spacing 8 with 3 bootstraps
#   Processing spacing 16 with 2 bootstraps
#
# Processing bin (4,1) - Density: 0.1394 - Current bootstraps: 50 - Current std: 1.662493 - Points: 451
#   Adding 63 more bootstraps to bin (4,1)
#   Processing spacing 1 with 50 bootstraps
#   Processing spacing 2 with 10 bootstraps
#   Processing spacing 4 with 2 bootstraps
#
# Processing bin (4,2) - Density: 0.1379 - Current bootstraps: 50 - Current std: 1.555113 - Points: 835
#   Adding 63 more bootstraps to bin (4,2)
#   Processing spacing 1 with 49 bootstraps
#   Processing spacing 2 with 9 bootstraps
#   Processing spacing 4 with 2 bootstraps
#
# Processing bin (3,1) - Density: 0.1370 - Current bootstraps: 50 - Current std: 0.700298 - Points: 227
#   Adding 63 more bootstraps to bin (3,1)
#   Processing spacing 1 with 49 bootstraps
#   Processing spacing 2 with 10 bootstraps
#   Processing spacing 4 with 2 bootstraps
#   Bin (3,1) CONVERGED after additional bootstraps with std 0.679353 <= 1.0
#
# Processing bin (4,3) - Density: 0.1367 - Current bootstraps: 50 - Current std: 1.435011 - Points: 1550
#   Adding 63 more bootstraps to bin (4,3)
#   Processing spacing 1 with 49 bootstraps
#   Processing spacing 2 with 10 bootstraps
#   Processing spacing 4 with 2 bootstraps
#
# Processing bin (3,2) - Density: 0.1347 - Current bootstraps: 50 - Current std: 0.679116 - Points: 418
#   Adding 63 more bootstraps to bin (3,2)
#   Processing spacing 1 with 49 bootstraps
#   Processing spacing 2 with 9 bootstraps
#   Processing spacing 4 with 3 bootstraps
#   Bin (3,2) CONVERGED after additional bootstraps with std 0.663018 <= 1.0
#
# Processing bin (4,4) - Density: 0.0758 - Current bootstraps: 50 - Current std: 1.445755 - Points: 1610
#   Adding 57 more bootstraps to bin (4,4)
#   Processing spacing 1 with 34 bootstraps
#   Processing spacing 2 with 16 bootstraps
#   Processing spacing 4 with 4 bootstraps
#   Processing spacing 8 with 1 bootstraps
#
# Processing bin (5,1) - Density: 0.0561 - Current bootstraps: 50 - Current std: 2.051975 - Points: 354
#   Adding 55 more bootstraps to bin (5,1)
#   Processing spacing 1 with 28 bootstraps
#   Processing spacing 2 with 21 bootstraps
#   Processing spacing 4 with 5 bootstraps
#
# Processing bin (5,3) - Density: 0.0550 - Current bootstraps: 50 - Current std: 2.157795 - Points: 1218
#   Adding 55 more bootstraps to bin (5,3)
#   Processing spacing 1 with 27 bootstraps
#   Processing spacing 2 with 20 bootstraps
#   Processing spacing 4 with 5 bootstraps
#   Processing spacing 8 with 1 bootstraps
#
# Processing bin (5,2) - Density: 0.0550 - Current bootstraps: 50 - Current std: 2.159743 - Points: 650
#   Adding 55 more bootstraps to bin (5,2)
#   Processing spacing 1 with 27 bootstraps
#   Processing spacing 2 with 20 bootstraps
#   Processing spacing 4 with 6 bootstraps
#
# Processing bin (5,4) - Density: 0.0404 - Current bootstraps: 50 - Current std: 2.115771 - Points: 1676
#   Adding 54 more bootstraps to bin (5,4)
#   Processing spacing 2 with 27 bootstraps
#   Processing spacing 1 with 16 bootstraps
#   Processing spacing 4 with 7 bootstraps
#   Processing spacing 8 with 1 bootstraps
#
# Processing bin (4,5) - Density: 0.0319 - Current bootstraps: 50 - Current std: 1.475007 - Points: 1267
#   Adding 53 more bootstraps to bin (4,5)
#   Processing spacing 2 with 28 bootstraps
#   Processing spacing 1 with 12 bootstraps
#   Processing spacing 4 with 9 bootstraps
#   Processing spacing 8 with 1 bootstraps
#
# Processing bin (5,5) - Density: 0.0258 - Current bootstraps: 50 - Current std: 2.232210 - Points: 2004
#   Adding 52 more bootstraps to bin (5,5)
#   Processing spacing 2 with 32 bootstraps
#   Processing spacing 4 with 11 bootstraps
#   Processing spacing 1 with 4 bootstraps
#   Processing spacing 8 with 2 bootstraps
#
# Processing bin (6,4) - Density: 0.0140 - Current bootstraps: 50 - Current std: 3.265129 - Points: 1133
#   Adding 51 more bootstraps to bin (6,4)
#   Processing spacing 2 with 24 bootstraps
#   Processing spacing 4 with 20 bootstraps
#   Processing spacing 8 with 5 bootstraps
#
# Processing bin (6,3) - Density: 0.0139 - Current bootstraps: 50 - Current std: 3.340822 - Points: 600
#   Adding 51 more bootstraps to bin (6,3)
#   Processing spacing 2 with 24 bootstraps
#   Processing spacing 4 with 21 bootstraps
#   Processing spacing 8 with 4 bootstraps
#   Processing spacing 16 with 1 bootstraps
#
# Processing bin (6,2) - Density: 0.0138 - Current bootstraps: 50 - Current std: 3.467500 - Points: 318
#   Adding 51 more bootstraps to bin (6,2)
#   Processing spacing 2 with 25 bootstraps
#   Processing spacing 4 with 22 bootstraps
#   Processing spacing 8 with 2 bootstraps
#
# Processing bin (6,5) - Density: 0.0124 - Current bootstraps: 50 - Current std: 3.140467 - Points: 1878
#   Adding 51 more bootstraps to bin (6,5)
#   Processing spacing 4 with 23 bootstraps
#   Processing spacing 2 with 21 bootstraps
#   Processing spacing 8 with 4 bootstraps
#   Processing spacing 16 with 1 bootstraps
#
# Processing bin (6,1) - Density: 0.0122 - Current bootstraps: 50 - Current std: 3.190621 - Points: 150
#   Adding 51 more bootstraps to bin (6,1)
#   Processing spacing 2 with 30 bootstraps
#   Processing spacing 4 with 20 bootstraps
#
# Processing bin (4,6) - Density: 0.0101 - Current bootstraps: 50 - Current std: 1.242054 - Points: 754
#   Adding 51 more bootstraps to bin (4,6)
#   Processing spacing 4 with 22 bootstraps
#   Processing spacing 2 with 20 bootstraps
#   Processing spacing 8 with 6 bootstraps
#   Processing spacing 16 with 1 bootstraps
#
# Processing bin (5,6) - Density: 0.0097 - Current bootstraps: 50 - Current std: 1.985061 - Points: 1411
#   Adding 50 more bootstraps to bin (5,6)
#   Processing spacing 4 with 23 bootstraps
#   Processing spacing 2 with 18 bootstraps
#   Processing spacing 8 with 5 bootstraps
#   Processing spacing 16 with 1 bootstraps
#
# Processing bin (6,6) - Density: 0.0074 - Current bootstraps: 50 - Current std: 3.090010 - Points: 2097
#   Adding 50 more bootstraps to bin (6,6)
#   Processing spacing 4 with 31 bootstraps
#   Processing spacing 2 with 8 bootstraps
#   Processing spacing 8 with 8 bootstraps
#   Processing spacing 16 with 1 bootstraps
#
# Processing bin (7,2) - Density: 0.0027 - Current bootstraps: 50 - Current std: 3.999043 - Points: 121
#   Adding 50 more bootstraps to bin (7,2)
#   Processing spacing 4 with 36 bootstraps
#   Processing spacing 8 with 13 bootstraps
#
# Processing bin (7,1) - Density: 0.0013 - Current bootstraps: 50 - Current std: 1.713524 - Points: 31
#   Adding 50 more bootstraps to bin (7,1)
#   Processing spacing 4 with 50 bootstraps
#
# Processing bin (8,5) - Density: 0.0008 - Current bootstraps: 50 - Current std: 1.405902 - Points: 448
#   Adding 50 more bootstraps to bin (8,5)
#   Processing spacing 8 with 25 bootstraps
#   Processing spacing 16 with 24 bootstraps
#
# Processing bin (8,4) - Density: 0.0007 - Current bootstraps: 50 - Current std: 1.442760 - Points: 227
#   Adding 50 more bootstraps to bin (8,4)
#   Processing spacing 8 with 35 bootstraps
#   Processing spacing 16 with 14 bootstraps
#
# Processing bin (8,6) - Density: 0.0007 - Current bootstraps: 50 - Current std: 1.474820 - Points: 789
#   Adding 50 more bootstraps to bin (8,6)
#   Processing spacing 8 with 29 bootstraps
#   Processing spacing 16 with 20 bootstraps
#
# Processing bin (8,7) - Density: 0.0007 - Current bootstraps: 50 - Current std: 1.444808 - Points: 1467
#   Adding 50 more bootstraps to bin (8,7)
#   Processing spacing 8 with 29 bootstraps
#   Processing spacing 16 with 20 bootstraps
#
# Processing bin (8,3) - Density: 0.0007 - Current bootstraps: 50 - Current std: 1.496901 - Points: 119
#   Adding 50 more bootstraps to bin (8,3)
#   Processing spacing 8 with 31 bootstraps
#   Processing spacing 16 with 18 bootstraps
#
# Processing bin (8,8) - Density: 0.0005 - Current bootstraps: 50 - Current std: 1.461514 - Points: 1813
#   Adding 50 more bootstraps to bin (8,8)
#   Processing spacing 16 with 31 bootstraps
#   Processing spacing 8 with 18 bootstraps
#
# Processing bin (8,2) - Density: 0.0003 - Current bootstraps: 50 - Current std: 1.273782 - Points: 25
#   Adding 50 more bootstraps to bin (8,2)
#   Processing spacing 8 with 50 bootstraps
#
# Processing bin (9,5) - Density: 0.0002 - Current bootstraps: 50 - Current std: 1.514179 - Points: 180
#   Adding 50 more bootstraps to bin (9,5)
#   Processing spacing 16 with 50 bootstraps
#
# Processing bin (8,9) - Density: 0.0001 - Current bootstraps: 50 - Current std: 1.066474 - Points: 1033
#   Adding 50 more bootstraps to bin (8,9)
#   Processing spacing 16 with 50 bootstraps
#
# Processing bin (9,6) - Density: 0.0001 - Current bootstraps: 50 - Current std: 1.218946 - Points: 261
#   Adding 50 more bootstraps to bin (9,6)
#   Processing spacing 16 with 50 bootstraps
#
# Processing bin (9,7) - Density: 0.0001 - Current bootstraps: 50 - Current std: 0.959679 - Points: 485
#   Adding 50 more bootstraps to bin (9,7)
#   Processing spacing 16 with 50 bootstraps
#   Bin (9,7) CONVERGED after additional bootstraps with std 0.942260 <= 1.0
#
# Processing bin (9,3) - Density: 0.0001 - Current bootstraps: 50 - Current std: 0.885988 - Points: 35
#   Adding 50 more bootstraps to bin (9,3)
#   Processing spacing 16 with 50 bootstraps
#   Bin (9,3) CONVERGED after additional bootstraps with std 0.881043 <= 1.0
#
# Processing bin (9,4) - Density: 0.0001 - Current bootstraps: 50 - Current std: 1.526260 - Points: 55
#   Adding 50 more bootstraps to bin (9,4)
#   Processing spacing 16 with 50 bootstraps
#
# Processing bin (9,9) - Density: 0.0001 - Current bootstraps: 50 - Current std: 0.920569 - Points: 847
#   Adding 50 more bootstraps to bin (9,9)
#   Processing spacing 16 with 50 bootstraps
#   Bin (9,9) CONVERGED after additional bootstraps with std 0.921748 <= 1.0
#
# Iteration 2 - 33 unconverged bins
#
# Processing bin (4,0) - Density: 0.3531 - Current bootstraps: 133 - Current std: 1.264251 - Points: 610
#   Adding 85 more bootstraps to bin (4,0)
#   Processing spacing 1 with 62 bootstraps
#   Processing spacing 2 with 14 bootstraps
#   Processing spacing 4 with 4 bootstraps
#   Processing spacing 8 with 2 bootstraps
#   Processing spacing 16 with 1 bootstraps
#   Bin (4,0) reached MAX BOOTSTRAPS 200
#
# Processing bin (5,0) - Density: 0.1545 - Current bootstraps: 112 - Current std: 1.768132 - Points: 521
#   Adding 65 more bootstraps to bin (5,0)
#   Processing spacing 1 with 27 bootstraps
#   Processing spacing 2 with 23 bootstraps
#   Processing spacing 4 with 7 bootstraps
#   Processing spacing 8 with 3 bootstraps
#   Processing spacing 16 with 2 bootstraps
#
# Processing bin (4,1) - Density: 0.1394 - Current bootstraps: 112 - Current std: 1.299655 - Points: 451
#   Adding 63 more bootstraps to bin (4,1)
#   Processing spacing 1 with 50 bootstraps
#   Processing spacing 2 with 10 bootstraps
#   Processing spacing 4 with 2 bootstraps
#
# Processing bin (4,2) - Density: 0.1379 - Current bootstraps: 110 - Current std: 1.226317 - Points: 835
#   Adding 63 more bootstraps to bin (4,2)
#   Processing spacing 1 with 49 bootstraps
#   Processing spacing 2 with 9 bootstraps
#   Processing spacing 4 with 2 bootstraps
#
# Processing bin (4,3) - Density: 0.1367 - Current bootstraps: 111 - Current std: 1.120774 - Points: 1550
#   Adding 63 more bootstraps to bin (4,3)
#   Processing spacing 1 with 49 bootstraps
#   Processing spacing 2 with 10 bootstraps
#   Processing spacing 4 with 2 bootstraps
#
# Processing bin (4,4) - Density: 0.0758 - Current bootstraps: 105 - Current std: 1.086044 - Points: 1610
#   Adding 57 more bootstraps to bin (4,4)
#   Processing spacing 1 with 34 bootstraps
#   Processing spacing 2 with 16 bootstraps
#   Processing spacing 4 with 4 bootstraps
#   Processing spacing 8 with 1 bootstraps
#
# Processing bin (5,1) - Density: 0.0561 - Current bootstraps: 104 - Current std: 2.073614 - Points: 354
#   Adding 55 more bootstraps to bin (5,1)
#   Processing spacing 1 with 28 bootstraps
#   Processing spacing 2 with 21 bootstraps
#   Processing spacing 4 with 5 bootstraps
#
# Processing bin (5,3) - Density: 0.0550 - Current bootstraps: 103 - Current std: 1.903546 - Points: 1218
#   Adding 55 more bootstraps to bin (5,3)
#   Processing spacing 1 with 27 bootstraps
#   Processing spacing 2 with 20 bootstraps
#   Processing spacing 4 with 5 bootstraps
#   Processing spacing 8 with 1 bootstraps
#
# Processing bin (5,2) - Density: 0.0550 - Current bootstraps: 103 - Current std: 2.066449 - Points: 650
#   Adding 55 more bootstraps to bin (5,2)
#   Processing spacing 1 with 27 bootstraps
#   Processing spacing 2 with 20 bootstraps
#   Processing spacing 4 with 6 bootstraps
#
# Processing bin (5,4) - Density: 0.0404 - Current bootstraps: 101 - Current std: 1.787045 - Points: 1676
#   Adding 54 more bootstraps to bin (5,4)
#   Processing spacing 2 with 27 bootstraps
#   Processing spacing 1 with 16 bootstraps
#   Processing spacing 4 with 7 bootstraps
#   Processing spacing 8 with 1 bootstraps
#
# Processing bin (4,5) - Density: 0.0319 - Current bootstraps: 100 - Current std: 1.058207 - Points: 1267
#   Adding 53 more bootstraps to bin (4,5)
#   Processing spacing 2 with 28 bootstraps
#   Processing spacing 1 with 12 bootstraps
#   Processing spacing 4 with 9 bootstraps
#   Processing spacing 8 with 1 bootstraps
#
# Processing bin (5,5) - Density: 0.0258 - Current bootstraps: 99 - Current std: 1.709992 - Points: 2004
#   Adding 52 more bootstraps to bin (5,5)
#   Processing spacing 2 with 32 bootstraps
#   Processing spacing 4 with 11 bootstraps
#   Processing spacing 1 with 4 bootstraps
#   Processing spacing 8 with 2 bootstraps
#
# Processing bin (6,4) - Density: 0.0140 - Current bootstraps: 99 - Current std: 2.552814 - Points: 1133
#   Adding 51 more bootstraps to bin (6,4)
#   Processing spacing 2 with 24 bootstraps
#   Processing spacing 4 with 20 bootstraps
#   Processing spacing 8 with 5 bootstraps
#
# Processing bin (6,3) - Density: 0.0139 - Current bootstraps: 100 - Current std: 2.802250 - Points: 600
#   Adding 51 more bootstraps to bin (6,3)
#   Processing spacing 2 with 24 bootstraps
#   Processing spacing 4 with 21 bootstraps
#   Processing spacing 8 with 4 bootstraps
#   Processing spacing 16 with 1 bootstraps
#
# Processing bin (6,2) - Density: 0.0138 - Current bootstraps: 99 - Current std: 3.180605 - Points: 318
#   Adding 51 more bootstraps to bin (6,2)
#   Processing spacing 2 with 25 bootstraps
#   Processing spacing 4 with 22 bootstraps
#   Processing spacing 8 with 2 bootstraps
#
# Processing bin (6,5) - Density: 0.0124 - Current bootstraps: 99 - Current std: 2.457835 - Points: 1878
#   Adding 51 more bootstraps to bin (6,5)
#   Processing spacing 4 with 23 bootstraps
#   Processing spacing 2 with 21 bootstraps
#   Processing spacing 8 with 4 bootstraps
#   Processing spacing 16 with 1 bootstraps
#
# Processing bin (6,1) - Density: 0.0122 - Current bootstraps: 100 - Current std: 3.040880 - Points: 150
#   Adding 51 more bootstraps to bin (6,1)
#   Processing spacing 2 with 30 bootstraps
#   Processing spacing 4 with 20 bootstraps
#
# Processing bin (4,6) - Density: 0.0101 - Current bootstraps: 99 - Current std: 0.930069 - Points: 754
#   Adding 51 more bootstraps to bin (4,6)
#   Processing spacing 4 with 22 bootstraps
#   Processing spacing 2 with 20 bootstraps
#   Processing spacing 8 with 6 bootstraps
#   Processing spacing 16 with 1 bootstraps
#   Bin (4,6) CONVERGED after additional bootstraps with std 0.923403 <= 1.0
#
# Processing bin (5,6) - Density: 0.0097 - Current bootstraps: 97 - Current std: 1.519240 - Points: 1411
#   Adding 50 more bootstraps to bin (5,6)
#   Processing spacing 4 with 23 bootstraps
#   Processing spacing 2 with 18 bootstraps
#   Processing spacing 8 with 5 bootstraps
#   Processing spacing 16 with 1 bootstraps
#
# Processing bin (6,6) - Density: 0.0074 - Current bootstraps: 98 - Current std: 2.441600 - Points: 2097
#   Adding 50 more bootstraps to bin (6,6)
#   Processing spacing 4 with 31 bootstraps
#   Processing spacing 2 with 8 bootstraps
#   Processing spacing 8 with 8 bootstraps
#   Processing spacing 16 with 1 bootstraps
#
# Processing bin (7,2) - Density: 0.0027 - Current bootstraps: 99 - Current std: 3.588511 - Points: 121
#   Adding 50 more bootstraps to bin (7,2)
#   Processing spacing 4 with 36 bootstraps
#   Processing spacing 8 with 13 bootstraps
#
# Processing bin (7,1) - Density: 0.0013 - Current bootstraps: 100 - Current std: 1.703822 - Points: 31
#   Adding 50 more bootstraps to bin (7,1)
#   Processing spacing 4 with 50 bootstraps
#
# Processing bin (8,5) - Density: 0.0008 - Current bootstraps: 99 - Current std: 1.458785 - Points: 448
#   Adding 50 more bootstraps to bin (8,5)
#   Processing spacing 8 with 25 bootstraps
#   Processing spacing 16 with 24 bootstraps
#
# Processing bin (8,4) - Density: 0.0007 - Current bootstraps: 99 - Current std: 1.495635 - Points: 227
#   Adding 50 more bootstraps to bin (8,4)
#   Processing spacing 8 with 35 bootstraps
#   Processing spacing 16 with 14 bootstraps
#
# Processing bin (8,6) - Density: 0.0007 - Current bootstraps: 99 - Current std: 1.445439 - Points: 789
#   Adding 50 more bootstraps to bin (8,6)
#   Processing spacing 8 with 29 bootstraps
#   Processing spacing 16 with 20 bootstraps
#
# Processing bin (8,7) - Density: 0.0007 - Current bootstraps: 99 - Current std: 1.421250 - Points: 1467
#   Adding 50 more bootstraps to bin (8,7)
#   Processing spacing 8 with 29 bootstraps
#   Processing spacing 16 with 20 bootstraps
#
# Processing bin (8,3) - Density: 0.0007 - Current bootstraps: 99 - Current std: 1.512418 - Points: 119
#   Adding 50 more bootstraps to bin (8,3)
#   Processing spacing 8 with 31 bootstraps
#   Processing spacing 16 with 18 bootstraps
#
# Processing bin (8,8) - Density: 0.0005 - Current bootstraps: 99 - Current std: 1.443535 - Points: 1813
#   Adding 50 more bootstraps to bin (8,8)
#   Processing spacing 16 with 31 bootstraps
#   Processing spacing 8 with 18 bootstraps
#
# Processing bin (8,2) - Density: 0.0003 - Current bootstraps: 100 - Current std: 1.290379 - Points: 25
#   Adding 50 more bootstraps to bin (8,2)
#   Processing spacing 8 with 50 bootstraps
#
# Processing bin (9,5) - Density: 0.0002 - Current bootstraps: 100 - Current std: 1.316473 - Points: 180
#   Adding 50 more bootstraps to bin (9,5)
#   Processing spacing 16 with 50 bootstraps
#
# Processing bin (8,9) - Density: 0.0001 - Current bootstraps: 100 - Current std: 1.080110 - Points: 1033
#   Adding 50 more bootstraps to bin (8,9)
#   Processing spacing 16 with 50 bootstraps
#
# Processing bin (9,6) - Density: 0.0001 - Current bootstraps: 100 - Current std: 1.144621 - Points: 261
#   Adding 50 more bootstraps to bin (9,6)
#   Processing spacing 16 with 50 bootstraps
#
# Processing bin (9,4) - Density: 0.0001 - Current bootstraps: 100 - Current std: 1.521078 - Points: 55
#   Adding 50 more bootstraps to bin (9,4)
#   Processing spacing 16 with 50 bootstraps
#
# Iteration 3 - 31 unconverged bins
#
# Processing bin (5,0) - Density: 0.1545 - Current bootstraps: 174 - Current std: 1.765763 - Points: 521
#   Adding 65 more bootstraps to bin (5,0)
#   Processing spacing 1 with 27 bootstraps
#   Processing spacing 2 with 23 bootstraps
#   Processing spacing 4 with 7 bootstraps
#   Processing spacing 8 with 3 bootstraps
#   Processing spacing 16 with 2 bootstraps
#   Bin (5,0) reached MAX BOOTSTRAPS 200
#
# Processing bin (4,1) - Density: 0.1394 - Current bootstraps: 174 - Current std: 1.271385 - Points: 451
#   Adding 63 more bootstraps to bin (4,1)
#   Processing spacing 1 with 50 bootstraps
#   Processing spacing 2 with 10 bootstraps
#   Processing spacing 4 with 2 bootstraps
#   Bin (4,1) reached MAX BOOTSTRAPS 200
#
# Processing bin (4,2) - Density: 0.1379 - Current bootstraps: 170 - Current std: 1.187605 - Points: 835
#   Adding 63 more bootstraps to bin (4,2)
#   Processing spacing 1 with 49 bootstraps
#   Processing spacing 2 with 9 bootstraps
#   Processing spacing 4 with 2 bootstraps
#   Bin (4,2) reached MAX BOOTSTRAPS 200
#
# Processing bin (4,3) - Density: 0.1367 - Current bootstraps: 172 - Current std: 1.074152 - Points: 1550
#   Adding 63 more bootstraps to bin (4,3)
#   Processing spacing 1 with 49 bootstraps
#   Processing spacing 2 with 10 bootstraps
#   Processing spacing 4 with 2 bootstraps
#   Bin (4,3) reached MAX BOOTSTRAPS 200
#
# Processing bin (4,4) - Density: 0.0758 - Current bootstraps: 160 - Current std: 1.022527 - Points: 1610
#   Adding 57 more bootstraps to bin (4,4)
#   Processing spacing 1 with 34 bootstraps
#   Processing spacing 2 with 16 bootstraps
#   Processing spacing 4 with 4 bootstraps
#   Processing spacing 8 with 1 bootstraps
#   Bin (4,4) reached MAX BOOTSTRAPS 200
#
# Processing bin (5,1) - Density: 0.0561 - Current bootstraps: 158 - Current std: 2.072515 - Points: 354
#   Adding 55 more bootstraps to bin (5,1)
#   Processing spacing 1 with 28 bootstraps
#   Processing spacing 2 with 21 bootstraps
#   Processing spacing 4 with 5 bootstraps
#   Bin (5,1) reached MAX BOOTSTRAPS 200
#
# Processing bin (5,3) - Density: 0.0550 - Current bootstraps: 156 - Current std: 1.855753 - Points: 1218
#   Adding 55 more bootstraps to bin (5,3)
#   Processing spacing 1 with 27 bootstraps
#   Processing spacing 2 with 20 bootstraps
#   Processing spacing 4 with 5 bootstraps
#   Processing spacing 8 with 1 bootstraps
#   Bin (5,3) reached MAX BOOTSTRAPS 200
#
# Processing bin (5,2) - Density: 0.0550 - Current bootstraps: 156 - Current std: 2.038582 - Points: 650
#   Adding 55 more bootstraps to bin (5,2)
#   Processing spacing 1 with 27 bootstraps
#   Processing spacing 2 with 20 bootstraps
#   Processing spacing 4 with 6 bootstraps
#   Bin (5,2) reached MAX BOOTSTRAPS 200
#
# Processing bin (5,4) - Density: 0.0404 - Current bootstraps: 152 - Current std: 1.726196 - Points: 1676
#   Adding 54 more bootstraps to bin (5,4)
#   Processing spacing 2 with 27 bootstraps
#   Processing spacing 1 with 16 bootstraps
#   Processing spacing 4 with 7 bootstraps
#   Processing spacing 8 with 1 bootstraps
#   Bin (5,4) reached MAX BOOTSTRAPS 200
#
# Processing bin (4,5) - Density: 0.0319 - Current bootstraps: 150 - Current std: 0.994909 - Points: 1267
#   Adding 53 more bootstraps to bin (4,5)
#   Processing spacing 2 with 28 bootstraps
#   Processing spacing 1 with 12 bootstraps
#   Processing spacing 4 with 9 bootstraps
#   Processing spacing 8 with 1 bootstraps
#   Bin (4,5) reached MAX BOOTSTRAPS 200
#
# Processing bin (5,5) - Density: 0.0258 - Current bootstraps: 148 - Current std: 1.628320 - Points: 2004
#   Adding 52 more bootstraps to bin (5,5)
#   Processing spacing 2 with 32 bootstraps
#   Processing spacing 4 with 11 bootstraps
#   Processing spacing 1 with 4 bootstraps
#   Processing spacing 8 with 2 bootstraps
#
# Processing bin (6,4) - Density: 0.0140 - Current bootstraps: 148 - Current std: 2.470038 - Points: 1133
#   Adding 51 more bootstraps to bin (6,4)
#   Processing spacing 2 with 24 bootstraps
#   Processing spacing 4 with 20 bootstraps
#   Processing spacing 8 with 5 bootstraps
#
# Processing bin (6,3) - Density: 0.0139 - Current bootstraps: 150 - Current std: 2.711464 - Points: 600
#   Adding 51 more bootstraps to bin (6,3)
#   Processing spacing 2 with 24 bootstraps
#   Processing spacing 4 with 21 bootstraps
#   Processing spacing 8 with 4 bootstraps
#   Processing spacing 16 with 1 bootstraps
#   Bin (6,3) reached MAX BOOTSTRAPS 200
#
# Processing bin (6,2) - Density: 0.0138 - Current bootstraps: 148 - Current std: 3.093458 - Points: 318
#   Adding 51 more bootstraps to bin (6,2)
#   Processing spacing 2 with 25 bootstraps
#   Processing spacing 4 with 22 bootstraps
#   Processing spacing 8 with 2 bootstraps
#
# Processing bin (6,5) - Density: 0.0124 - Current bootstraps: 148 - Current std: 2.360520 - Points: 1878
#   Adding 51 more bootstraps to bin (6,5)
#   Processing spacing 4 with 23 bootstraps
#   Processing spacing 2 with 21 bootstraps
#   Processing spacing 8 with 4 bootstraps
#   Processing spacing 16 with 1 bootstraps
#
# Processing bin (6,1) - Density: 0.0122 - Current bootstraps: 150 - Current std: 2.966622 - Points: 150
#   Adding 51 more bootstraps to bin (6,1)
#   Processing spacing 2 with 30 bootstraps
#   Processing spacing 4 with 20 bootstraps
#   Bin (6,1) reached MAX BOOTSTRAPS 200
#
# Processing bin (5,6) - Density: 0.0097 - Current bootstraps: 144 - Current std: 1.439112 - Points: 1411
#   Adding 50 more bootstraps to bin (5,6)
#   Processing spacing 4 with 23 bootstraps
#   Processing spacing 2 with 18 bootstraps
#   Processing spacing 8 with 5 bootstraps
#   Processing spacing 16 with 1 bootstraps
#
# Processing bin (6,6) - Density: 0.0074 - Current bootstraps: 146 - Current std: 2.317563 - Points: 2097
#   Adding 50 more bootstraps to bin (6,6)
#   Processing spacing 4 with 31 bootstraps
#   Processing spacing 2 with 8 bootstraps
#   Processing spacing 8 with 8 bootstraps
#   Processing spacing 16 with 1 bootstraps
#
# Processing bin (7,2) - Density: 0.0027 - Current bootstraps: 148 - Current std: 3.466995 - Points: 121
#   Adding 50 more bootstraps to bin (7,2)
#   Processing spacing 4 with 36 bootstraps
#   Processing spacing 8 with 13 bootstraps
#
# Processing bin (7,1) - Density: 0.0013 - Current bootstraps: 150 - Current std: 1.712741 - Points: 31
#   Adding 50 more bootstraps to bin (7,1)
#   Processing spacing 4 with 50 bootstraps
#   Bin (7,1) reached MAX BOOTSTRAPS 200
#
# Processing bin (8,5) - Density: 0.0008 - Current bootstraps: 148 - Current std: 1.466660 - Points: 448
#   Adding 50 more bootstraps to bin (8,5)
#   Processing spacing 8 with 25 bootstraps
#   Processing spacing 16 with 24 bootstraps
#
# Processing bin (8,4) - Density: 0.0007 - Current bootstraps: 148 - Current std: 1.505128 - Points: 227
#   Adding 50 more bootstraps to bin (8,4)
#   Processing spacing 8 with 35 bootstraps
#   Processing spacing 16 with 14 bootstraps
#
# Processing bin (8,6) - Density: 0.0007 - Current bootstraps: 148 - Current std: 1.448040 - Points: 789
#   Adding 50 more bootstraps to bin (8,6)
#   Processing spacing 8 with 29 bootstraps
#   Processing spacing 16 with 20 bootstraps
#
# Processing bin (8,7) - Density: 0.0007 - Current bootstraps: 148 - Current std: 1.422404 - Points: 1467
#   Adding 50 more bootstraps to bin (8,7)
#   Processing spacing 8 with 29 bootstraps
#   Processing spacing 16 with 20 bootstraps
#
# Processing bin (8,3) - Density: 0.0007 - Current bootstraps: 148 - Current std: 1.511562 - Points: 119
#   Adding 50 more bootstraps to bin (8,3)
#   Processing spacing 8 with 31 bootstraps
#   Processing spacing 16 with 18 bootstraps
#
# Processing bin (8,8) - Density: 0.0005 - Current bootstraps: 148 - Current std: 1.443781 - Points: 1813
#   Adding 50 more bootstraps to bin (8,8)
#   Processing spacing 16 with 31 bootstraps
#   Processing spacing 8 with 18 bootstraps
#
# Processing bin (8,2) - Density: 0.0003 - Current bootstraps: 150 - Current std: 1.293870 - Points: 25
#   Adding 50 more bootstraps to bin (8,2)
#   Processing spacing 8 with 50 bootstraps
#   Bin (8,2) reached MAX BOOTSTRAPS 200
#
# Processing bin (9,5) - Density: 0.0002 - Current bootstraps: 150 - Current std: 1.311263 - Points: 180
#   Adding 50 more bootstraps to bin (9,5)
#   Processing spacing 16 with 50 bootstraps
#   Bin (9,5) reached MAX BOOTSTRAPS 200
#
# Processing bin (8,9) - Density: 0.0001 - Current bootstraps: 150 - Current std: 1.080536 - Points: 1033
#   Adding 50 more bootstraps to bin (8,9)
#   Processing spacing 16 with 50 bootstraps
#   Bin (8,9) reached MAX BOOTSTRAPS 200
#
# Processing bin (9,6) - Density: 0.0001 - Current bootstraps: 150 - Current std: 1.147272 - Points: 261
#   Adding 50 more bootstraps to bin (9,6)
#   Processing spacing 16 with 50 bootstraps
#   Bin (9,6) reached MAX BOOTSTRAPS 200
#
# Processing bin (9,4) - Density: 0.0001 - Current bootstraps: 150 - Current std: 1.527583 - Points: 55
#   Adding 50 more bootstraps to bin (9,4)
#   Processing spacing 16 with 50 bootstraps
#   Bin (9,4) reached MAX BOOTSTRAPS 200
#
# Iteration 4 - 13 unconverged bins
#
# Processing bin (5,5) - Density: 0.0258 - Current bootstraps: 197 - Current std: 1.532117 - Points: 2004
#   Adding 52 more bootstraps to bin (5,5)
#   Processing spacing 2 with 32 bootstraps
#   Processing spacing 4 with 11 bootstraps
#   Processing spacing 1 with 4 bootstraps
#   Processing spacing 8 with 2 bootstraps
#   Bin (5,5) reached MAX BOOTSTRAPS 200
#
# Processing bin (6,4) - Density: 0.0140 - Current bootstraps: 197 - Current std: 2.366451 - Points: 1133
#   Adding 51 more bootstraps to bin (6,4)
#   Processing spacing 2 with 24 bootstraps
#   Processing spacing 4 with 20 bootstraps
#   Processing spacing 8 with 5 bootstraps
#   Bin (6,4) reached MAX BOOTSTRAPS 200
#
# Processing bin (6,2) - Density: 0.0138 - Current bootstraps: 197 - Current std: 3.014098 - Points: 318
#   Adding 51 more bootstraps to bin (6,2)
#   Processing spacing 2 with 25 bootstraps
#   Processing spacing 4 with 22 bootstraps
#   Processing spacing 8 with 2 bootstraps
#   Bin (6,2) reached MAX BOOTSTRAPS 200
#
# Processing bin (6,5) - Density: 0.0124 - Current bootstraps: 197 - Current std: 2.234948 - Points: 1878
#   Adding 51 more bootstraps to bin (6,5)
#   Processing spacing 4 with 23 bootstraps
#   Processing spacing 2 with 21 bootstraps
#   Processing spacing 8 with 4 bootstraps
#   Processing spacing 16 with 1 bootstraps
#   Bin (6,5) reached MAX BOOTSTRAPS 200
#
# Processing bin (5,6) - Density: 0.0097 - Current bootstraps: 191 - Current std: 1.349049 - Points: 1411
#   Adding 50 more bootstraps to bin (5,6)
#   Processing spacing 4 with 23 bootstraps
#   Processing spacing 2 with 18 bootstraps
#   Processing spacing 8 with 5 bootstraps
#   Processing spacing 16 with 1 bootstraps
#   Bin (5,6) reached MAX BOOTSTRAPS 200
#
# Processing bin (6,6) - Density: 0.0074 - Current bootstraps: 194 - Current std: 2.185371 - Points: 2097
#   Adding 50 more bootstraps to bin (6,6)
#   Processing spacing 4 with 31 bootstraps
#   Processing spacing 2 with 8 bootstraps
#   Processing spacing 8 with 8 bootstraps
#   Processing spacing 16 with 1 bootstraps
#   Bin (6,6) reached MAX BOOTSTRAPS 200
#
# Processing bin (7,2) - Density: 0.0027 - Current bootstraps: 197 - Current std: 3.373513 - Points: 121
#   Adding 50 more bootstraps to bin (7,2)
#   Processing spacing 4 with 36 bootstraps
#   Processing spacing 8 with 13 bootstraps
#   Bin (7,2) reached MAX BOOTSTRAPS 200
#
# Processing bin (8,5) - Density: 0.0008 - Current bootstraps: 197 - Current std: 1.464985 - Points: 448
#   Adding 50 more bootstraps to bin (8,5)
#   Processing spacing 8 with 25 bootstraps
#   Processing spacing 16 with 24 bootstraps
#   Bin (8,5) reached MAX BOOTSTRAPS 200
#
# Processing bin (8,4) - Density: 0.0007 - Current bootstraps: 197 - Current std: 1.504810 - Points: 227
#   Adding 50 more bootstraps to bin (8,4)
#   Processing spacing 8 with 35 bootstraps
#   Processing spacing 16 with 14 bootstraps
#   Bin (8,4) reached MAX BOOTSTRAPS 200
#
# Processing bin (8,6) - Density: 0.0007 - Current bootstraps: 197 - Current std: 1.444270 - Points: 789
#   Adding 50 more bootstraps to bin (8,6)
#   Processing spacing 8 with 29 bootstraps
#   Processing spacing 16 with 20 bootstraps
#   Bin (8,6) reached MAX BOOTSTRAPS 200
#
# Processing bin (8,7) - Density: 0.0007 - Current bootstraps: 197 - Current std: 1.418519 - Points: 1467
#   Adding 50 more bootstraps to bin (8,7)
#   Processing spacing 8 with 29 bootstraps
#   Processing spacing 16 with 20 bootstraps
#   Bin (8,7) reached MAX BOOTSTRAPS 200
#
# Processing bin (8,3) - Density: 0.0007 - Current bootstraps: 197 - Current std: 1.506964 - Points: 119
#   Adding 50 more bootstraps to bin (8,3)
#   Processing spacing 8 with 31 bootstraps
#   Processing spacing 16 with 18 bootstraps
#   Bin (8,3) reached MAX BOOTSTRAPS 200
#
# Processing bin (8,8) - Density: 0.0005 - Current bootstraps: 197 - Current std: 1.439179 - Points: 1813
#   Adding 50 more bootstraps to bin (8,8)
#   Processing spacing 16 with 31 bootstraps
#   Processing spacing 8 with 18 bootstraps
#   Bin (8,8) reached MAX BOOTSTRAPS 200
# All bins have converged or reached max bootstraps!
#
# FINAL CONVERGENCE STATISTICS:
#   Total bins with data more than 10 points: 91
#   Converged bins: 91
#   Unconverged bins: 0
#   Bins at max bootstraps: 32
#
# Creating output dataset...
# 2D SF COMPLETED SUCCESSFULLY!
# ============================================================

# %% [markdown]
# # Plot 2D SFs

# %%
# Create figure with 3 subplots
fig, axes = plt.subplots(1, 3, figsize=(16, 5.5), constrained_layout=True)

# Common settings for all plots
plot_titles = ['Structure Function', 'Standard Error', 'Bootstraps Required']
cmaps = ['viridis', 'viridis', 'plasma']
labels = [r'$\delta T$ [°C]', r'$\delta T$ [°C]', 'Number of Bootstraps']

# Data to plot
data_to_plot = [sf_result.sf.T, sf_result.sf_std.T, sf_result.nbootstraps.T]

for i, (ax, data, title, cmap, label) in enumerate(zip(axes, data_to_plot, plot_titles, cmaps, labels)):
    # Create the plot with specific shading for the first plot
    if i == 0:
        im = ax.pcolormesh(sf_result.x, sf_result.y, data, cmap=cmap, shading='gouraud')
    else:
        im = ax.pcolormesh(sf_result.x, sf_result.y, data, cmap=cmap, shading='auto')
    
    # Add colorbar with proper formatting
    cbar = fig.colorbar(im, ax=ax)
    cbar.set_label(label, fontsize=11, fontweight='bold')
    
    # Set axis labels and title
    ax.set_xlabel(r'$r_x$ [m]', fontsize=11, fontweight='bold')
    if i == 0:
        ax.set_ylabel(r'$r_y$ [m]', fontsize=11, fontweight='bold')
    
    # Set log scales
    ax.set_xscale('log')
    ax.set_yscale('log')
    
    # Add title
    ax.set_title(title, fontsize=12, fontweight='bold', pad=10)
    
    # Customize spines
    for spine in ax.spines.values():
        spine.set_linewidth(1.5)
    
    # Customize tick parameters
    ax.tick_params(which='both', direction='in', width=1.2, length=5, 
                  labelsize=10, top=True, right=True)
        
    # Add scientific notation for axes
    ax.xaxis.set_major_formatter(ticker.LogFormatterSciNotation())
    ax.yaxis.set_major_formatter(ticker.LogFormatterSciNotation())

# Add main title for the entire figure
fig.suptitle('Gulf Stream Structure Function Analysis', fontsize=14, fontweight='bold', y=1.08)

# Add annotation explaining the analysis
fig.text(0.5, -0.08, 
         'Structure function analysis reveals spatial temperature variability across scales.\n'
         'Threshold value of 1°C highlights Gulf Stream frontal features.',
         ha='center', fontsize=10, fontstyle='italic')

plt.show()

# %% [markdown]
# # Calculate ISOTROPIC SST SF $\delta T(r)$

# %%
bins = {
    'r': np.logspace(np.log10(5000.), np.log10(1000000.0), 15),
}
iso_sf = psf.get_isotropic_sf_2d(
    ds=ds_new,
    variables_names=["sst"],
    order=1,
    bins=bins,
    fun='scalar',
    bootsize={'y':32,'x':32},
    initial_nbootstrap=50,
    max_nbootstrap=200,
    step_nbootstrap=50,
    convergence_eps=1.0,
    window_size_r=8,
    window_size_theta=10,
)
# Out:
# Dimensions ('y', 'x') are already in the expected order
# Using bootsize: {'y': 32, 'x': 32}
# Bootstrappable dimensions: ['y', 'x']
# Two bootstrappable dimensions. Available spacings: [1, 2, 4, 8, 16]
#
# ============================================================
# STARTING ISOTROPIC_SF WITH FUNCTION TYPE: scalar
# Variables: ['sst'], Order: 1
# Bootstrap parameters: initial=50, max=200, step=50
# Convergence threshold: 1.0
# Bootstrappable dimensions: ['y', 'x'] (count: 2)
# ============================================================
#
# Detected logarithmic binning for radial dimension
# Using 14 radial bins and 36 angular bins
# Using window size 10 for theta and 8 for r
# Available spacings: [1, 2, 4, 8, 16]
#
# INITIAL BOOTSTRAP PHASE
#   Processing spacing 1 with 10 bootstraps
#   Processing spacing 2 with 10 bootstraps
#   Processing spacing 4 with 10 bootstraps
#   Processing spacing 8 with 10 bootstraps
#   Processing spacing 16 with 10 bootstraps
#
# CALCULATING BIN DENSITIES
# Total points collected: 51190
# Bins with points: 14/14
# Maximum density bin has 16977 points
#
# CALCULATING INITIAL STATISTICS
# Marked 0 low-density bins (< 10 points) as converged
# Marked 0 bins with NaN standard deviations as converged
# Marked 8 bins as early-converged (std <= 1.0)
#
# STARTING ADAPTIVE CONVERGENCE LOOP
#
# Iteration 1 - 6 unconverged bins
#
# Processing bin 7 (r=85440.6699) - Density: 0.1579 - Current bootstraps: 50 - Current std: 1.170456 - Points: 3190
#   Adding up to 65 more bootstraps to bin 7
#   Processing spacing 1 with 46 bootstraps
#   Processing spacing 2 with 13 bootstraps
#   Processing spacing 4 with 3 bootstraps
#   Processing spacing 8 with 1 bootstraps
#
# Processing bin 8 (r=124745.2249) - Density: 0.1236 - Current bootstraps: 50 - Current std: 1.506418 - Points: 5324
#   Adding up to 62 more bootstraps to bin 8
#   Processing spacing 1 with 40 bootstraps
#   Processing spacing 2 with 16 bootstraps
#   Processing spacing 4 with 4 bootstraps
#
# Processing bin 9 (r=182130.7247) - Density: 0.0563 - Current bootstraps: 50 - Current std: 2.385300 - Points: 5169
#   Adding up to 55 more bootstraps to bin 9
#   Processing spacing 2 with 27 bootstraps
#   Processing spacing 1 with 16 bootstraps
#   Processing spacing 4 with 8 bootstraps
#   Processing spacing 8 with 2 bootstraps
#
# Processing bin 10 (r=265914.7948) - Density: 0.0299 - Current bootstraps: 50 - Current std: 3.153771 - Points: 5846
#   Adding up to 52 more bootstraps to bin 10
#   Processing spacing 2 with 33 bootstraps
#   Processing spacing 4 with 14 bootstraps
#   Processing spacing 8 with 3 bootstraps
#
# Processing bin 11 (r=388241.3482) - Density: 0.0122 - Current bootstraps: 50 - Current std: 2.603433 - Points: 5081
#   Adding up to 51 more bootstraps to bin 11
#   Processing spacing 4 with 28 bootstraps
#   Processing spacing 2 with 12 bootstraps
#   Processing spacing 8 with 7 bootstraps
#   Processing spacing 16 with 2 bootstraps
#
# Processing bin 13 (r=827599.7624) - Density: 0.0090 - Current bootstraps: 50 - Current std: 2.733814 - Points: 16977
#   Adding up to 50 more bootstraps to bin 13
#   Processing spacing 16 with 27 bootstraps
#   Processing spacing 8 with 20 bootstraps
#   Processing spacing 4 with 1 bootstraps
#
# Iteration 2 - 6 unconverged bins
#
# Processing bin 7 (r=85440.6699) - Density: 0.1579 - Current bootstraps: 113 - Current std: 1.008928 - Points: 3190
#   Adding up to 65 more bootstraps to bin 7
#   Processing spacing 1 with 46 bootstraps
#   Processing spacing 2 with 13 bootstraps
#   Processing spacing 4 with 3 bootstraps
#   Processing spacing 8 with 1 bootstraps
#   Bin 7 (r=85440.6699) CONVERGED with std 0.996928 <= 1.0
#
# Processing bin 8 (r=124745.2249) - Density: 0.1236 - Current bootstraps: 110 - Current std: 1.426717 - Points: 5324
#   Adding up to 62 more bootstraps to bin 8
#   Processing spacing 1 with 40 bootstraps
#   Processing spacing 2 with 16 bootstraps
#   Processing spacing 4 with 4 bootstraps
#
# Processing bin 9 (r=182130.7247) - Density: 0.0563 - Current bootstraps: 103 - Current std: 2.037699 - Points: 5169
#   Adding up to 55 more bootstraps to bin 9
#   Processing spacing 2 with 27 bootstraps
#   Processing spacing 1 with 16 bootstraps
#   Processing spacing 4 with 8 bootstraps
#   Processing spacing 8 with 2 bootstraps
#
# Processing bin 10 (r=265914.7948) - Density: 0.0299 - Current bootstraps: 100 - Current std: 2.622174 - Points: 5846
#   Adding up to 52 more bootstraps to bin 10
#   Processing spacing 2 with 33 bootstraps
#   Processing spacing 4 with 14 bootstraps
#   Processing spacing 8 with 3 bootstraps
#
# Processing bin 11 (r=388241.3482) - Density: 0.0122 - Current bootstraps: 99 - Current std: 2.420589 - Points: 5081
#   Adding up to 51 more bootstraps to bin 11
#   Processing spacing 4 with 28 bootstraps
#   Processing spacing 2 with 12 bootstraps
#   Processing spacing 8 with 7 bootstraps
#   Processing spacing 16 with 2 bootstraps
#
# Processing bin 13 (r=827599.7624) - Density: 0.0090 - Current bootstraps: 98 - Current std: 2.811862 - Points: 16977
#   Adding up to 50 more bootstraps to bin 13
#   Processing spacing 16 with 27 bootstraps
#   Processing spacing 8 with 20 bootstraps
#   Processing spacing 4 with 1 bootstraps
#
# Iteration 3 - 5 unconverged bins
#
# Processing bin 8 (r=124745.2249) - Density: 0.1236 - Current bootstraps: 170 - Current std: 1.423323 - Points: 5324
#   Adding up to 62 more bootstraps to bin 8
#   Processing spacing 1 with 40 bootstraps
#   Processing spacing 2 with 16 bootstraps
#   Processing spacing 4 with 4 bootstraps
#   Bin 8 (r=124745.2249) reached MAX BOOTSTRAPS 200
#
# Processing bin 9 (r=182130.7247) - Density: 0.0563 - Current bootstraps: 156 - Current std: 1.971801 - Points: 5169
#   Adding up to 55 more bootstraps to bin 9
#   Processing spacing 2 with 27 bootstraps
#   Processing spacing 1 with 16 bootstraps
#   Processing spacing 4 with 8 bootstraps
#   Processing spacing 8 with 2 bootstraps
#   Bin 9 (r=182130.7247) reached MAX BOOTSTRAPS 200
#
# Processing bin 10 (r=265914.7948) - Density: 0.0299 - Current bootstraps: 150 - Current std: 2.492623 - Points: 5846
#   Adding up to 52 more bootstraps to bin 10
#   Processing spacing 2 with 33 bootstraps
#   Processing spacing 4 with 14 bootstraps
#   Processing spacing 8 with 3 bootstraps
#   Bin 10 (r=265914.7948) reached MAX BOOTSTRAPS 200
#
# Processing bin 11 (r=388241.3482) - Density: 0.0122 - Current bootstraps: 148 - Current std: 2.381742 - Points: 5081
#   Adding up to 51 more bootstraps to bin 11
#   Processing spacing 4 with 28 bootstraps
#   Processing spacing 2 with 12 bootstraps
#   Processing spacing 8 with 7 bootstraps
#   Processing spacing 16 with 2 bootstraps
#
# Processing bin 13 (r=827599.7624) - Density: 0.0090 - Current bootstraps: 146 - Current std: 2.842758 - Points: 16977
#   Adding up to 50 more bootstraps to bin 13
#   Processing spacing 16 with 27 bootstraps
#   Processing spacing 8 with 20 bootstraps
#   Processing spacing 4 with 1 bootstraps
#
# Iteration 4 - 2 unconverged bins
#
# Processing bin 11 (r=388241.3482) - Density: 0.0122 - Current bootstraps: 197 - Current std: 2.303264 - Points: 5081
#   Adding up to 51 more bootstraps to bin 11
#   Processing spacing 4 with 28 bootstraps
#   Processing spacing 2 with 12 bootstraps
#   Processing spacing 8 with 7 bootstraps
#   Processing spacing 16 with 2 bootstraps
#   Bin 11 (r=388241.3482) reached MAX BOOTSTRAPS 200
#
# Processing bin 13 (r=827599.7624) - Density: 0.0090 - Current bootstraps: 194 - Current std: 2.797588 - Points: 16977
#   Adding up to 50 more bootstraps to bin 13
#   Processing spacing 16 with 27 bootstraps
#   Processing spacing 8 with 20 bootstraps
#   Processing spacing 4 with 1 bootstraps
#   Bin 13 (r=827599.7624) reached MAX BOOTSTRAPS 200
# All bins have converged or reached max bootstraps!
#
# FINAL CONVERGENCE STATISTICS:
#   Total bins with data more than 10 points: 14
#   Converged bins: 14
#   Unconverged bins: 0
#   Bins at max bootstraps: 5
#
# Calculating error metrics and confidence intervals...
#
# Creating output dataset...
# ISOTROPIC SF COMPLETED SUCCESSFULLY!
# ============================================================

# %% [markdown]
# # Plot Isotropic SF

# %%
# Create separate figures for better spacing and clarity
plt.figure(figsize=(10, 6))
# Structure Function with Confidence Interval
plt.plot(iso_sf.r, iso_sf.sf, 'b-', linewidth=2.5, label='Structure Function')
plt.fill_between(iso_sf.r, 
                iso_sf.ci_lower, 
                iso_sf.ci_upper, 
                alpha=0.3, color='blue')

# Formatting
plt.xlabel(r'$r$ [m]', fontsize=12, fontweight='bold')
plt.ylabel(r'$\delta T$ [°C]', fontsize=12, fontweight='bold')
plt.title('Isotropic Structure Function with Confidence Intervals', 
         fontsize=14, fontweight='bold', pad=10)
plt.legend(fontsize=11, frameon=True, facecolor='white', framealpha=0.9)
plt.grid(True, which='both', linestyle='--', alpha=0.6)
plt.xscale('log')

# Customize spines
ax = plt.gca()
for spine in ax.spines.values():
    spine.set_linewidth(1.5)

# Customize tick parameters
ax.tick_params(which='both', direction='in', width=1.2, length=5, 
              labelsize=10, top=True, right=True)
ax.xaxis.set_major_formatter(ticker.LogFormatterSciNotation())

plt.tight_layout()

# --------------------------------------------------
# Errors of Isotropy and Homogeneity
# --------------------------------------------------
plt.figure(figsize=(12, 5))

# Error of isotropy
plt.subplot(121)
plt.plot(iso_sf.r, iso_sf.error_isotropy, 'b-', linewidth=2.5)
plt.xlabel(r'$r$ [m]', fontsize=12, fontweight='bold')
plt.ylabel('Error of Isotropy [°C]', fontsize=12, fontweight='bold')
plt.title('Error of Isotropy (Variation with Angle)', 
         fontsize=14, fontweight='bold', pad=10)
plt.grid(True, which='both', linestyle='--', alpha=0.6)
plt.xscale('log')

# Customize spines and ticks
ax = plt.gca()
for spine in ax.spines.values():
    spine.set_linewidth(1.5)
ax.tick_params(which='both', direction='in', width=1.2, length=5, 
              labelsize=10, top=True, right=True)
ax.xaxis.set_major_formatter(ticker.LogFormatterSciNotation())

# Error of homogeneity
plt.subplot(122)
plt.plot(iso_sf.r_subset, iso_sf.error_homogeneity, 'b-', linewidth=2.5)
plt.xlabel(r'$r$ [m]', fontsize=12, fontweight='bold')
plt.ylabel('Error of Homogeneity [°C]', fontsize=12, fontweight='bold')
plt.title('Error of Homogeneity (Variation with Radius)', 
         fontsize=14, fontweight='bold', pad=10)
plt.grid(True, which='both', linestyle='--', alpha=0.6)
plt.xscale('log')

# Customize spines and ticks
ax = plt.gca()
for spine in ax.spines.values():
    spine.set_linewidth(1.5)
ax.tick_params(which='both', direction='in', width=1.2, length=5, 
              labelsize=10, top=True, right=True)
ax.xaxis.set_major_formatter(ticker.LogFormatterSciNotation())

plt.tight_layout()

# --------------------------------------------------
# Polar representation of structure function
# --------------------------------------------------
plt.figure(figsize=(8, 8))
ax = plt.subplot(111, polar=True)

# Longitudinal structure function
pcm = ax.pcolormesh(iso_sf.theta, iso_sf.r, iso_sf.sf_polar.T, 
                   cmap='viridis', shading='gouraud')
ax.set_title('Structure Function in Polar Coordinates', 
            fontsize=14, fontweight='bold', pad=20)

# Add custom colorbar with proper labeling
cbar = plt.colorbar(pcm, pad=0.15)
cbar.set_label(r'$\delta T$ [°C]', fontsize=12, fontweight='bold')

# Annotate directional features
ax.text(0, ax.get_rmax()*1.05, 'Zonal', 
       ha='center', va='center', fontweight='bold')
ax.text(np.pi/2, ax.get_rmax()*1.05, 'Meridional', 
       ha='center', va='center', fontweight='bold')

plt.tight_layout()
plt.show()
